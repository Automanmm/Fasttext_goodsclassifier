# %%
# 模块加载
import pandas as pd
import numpy as np
import jieba
import fasttext

# %%
# 数据加载
train = pd.read_csv('train.tsv', sep='\t', encoding='gb18030')
train.head()
# Out:
#                                       ITEM_NAME              TYPE
# 0               腾讯QQ黄钻三个月QQ黄钻3个月季卡官方自动充值可查时间可续费  本地生活--游戏充值--QQ充值
# 1                      腾讯q币充值30元qq币30qb30q币自动充值  本地生活--游戏充值--QQ充值
# 2                      腾讯QQ红钻包月卡 QQ红钻一个月QQ红钻1个月  本地生活--游戏充值--QQ充值
# 3                                腾讯QQ蓝钻贵族31个月直充  本地生活--游戏充值--QQ充值
# 4  腾讯QQ币148元148QQ币148个直充148Q币148个Q币148个QQB★自动充值  本地生活--游戏充值--QQ充值

# %%
# 第一层第二层第三层类别转序列号
typeitems = np.array([x.split('--') for x in train['TYPE']])
train['TYPE1'] = typeitems[:,0]
train['TYPE2'] = typeitems[:,1]
train['TYPE3'] = typeitems[:,2]

type_dict = {}
for tp in train['TYPE1']:
    if tp not in type_dict.keys():
        type_dict[tp] = len(type_dict)
train['TYPE_NUM1'] = [type_dict[tp] for tp in train['TYPE1']]
print('第一层类别总数：%d' % (len(type_dict)))

type2_dict = {}
for tp in train['TYPE2']:
    if tp not in type2_dict.keys():
        type2_dict[tp] = len(type2_dict)
train['TYPE_NUM2'] = [type2_dict[tp] for tp in train['TYPE2']]
print('第二层类别总数：%d' % (len(type2_dict)))

type3_dict = {}
for tp in train['TYPE3']:
    if tp not in type3_dict.keys():
        type3_dict[tp] = len(type3_dict)
train['TYPE_NUM3'] = [type3_dict[tp] for tp in train['TYPE3']]
print('第三层类别总数：%d' % (len(type3_dict)))

train.head()
# Out:
# 第一层类别总数：22
# 第二层类别总数：191
# 第三层类别总数：1193
#                                       ITEM_NAME              TYPE TYPE1 TYPE2  \
# 0               腾讯QQ黄钻三个月QQ黄钻3个月季卡官方自动充值可查时间可续费  本地生活--游戏充值--QQ充值  本地生活  游戏充值
# 1                      腾讯q币充值30元qq币30qb30q币自动充值  本地生活--游戏充值--QQ充值  本地生活  游戏充值
# 2                      腾讯QQ红钻包月卡 QQ红钻一个月QQ红钻1个月  本地生活--游戏充值--QQ充值  本地生活  游戏充值
# 3                                腾讯QQ蓝钻贵族31个月直充  本地生活--游戏充值--QQ充值  本地生活  游戏充值
# 4  腾讯QQ币148元148QQ币148个直充148Q币148个Q币148个QQB★自动充值  本地生活--游戏充值--QQ充值  本地生活  游戏充值
#
#   TYPE3  TYPE_NUM1  TYPE_NUM2  TYPE_NUM3
# 0  QQ充值          0          0          0
# 1  QQ充值          0          0          0
# 2  QQ充值          0          0          0
# 3  QQ充值          0          0          0
# 4  QQ充值          0          0          0

# %%
# 根据第一层第二层构造第二层第三层分类索引
type2_list = []
for i in range(len(type_dict)):
    a = train[train.TYPE_NUM1 == i].index.tolist()
    type2_list.append(a)

type3_list = []
for i in range(len(type2_dict)):
    a = train[train.TYPE_NUM2 == i].index.tolist()
    type3_list.append(a)

# %%
# 数据打乱，切分训练集和测试集
def train_test_split(x, y, seed = 10):
    np.random.seed(seed)
    shuffle_indices = np.random.permutation(np.arange(len(x)))
    x_shuffled = x[shuffle_indices]
    y_shuffled = y[shuffle_indices]

    x_train = x_shuffled[:int(len(x)*0.95)]
    y_train = y_shuffled[:int(len(x)*0.95)]

    x_test = x_shuffled[int(len(x)*0.95):]
    y_test = y_shuffled[int(len(x)*0.95):]
    
    x_train = np.array(x_train)
    y_train = np.array(y_train)
    x_test = np.array(x_test)
    y_test = np.array(y_test)
    return x_train, y_train, x_test, y_test

# 写标准fasttext标准文件
def data_write(filename, x, y):
    with open(filename, 'w') as f:
        for i, doc in enumerate(x):
            doc = jieba.cut(doc.strip(), cut_all=False)
            doc = ' '.join(list(doc))
            predix = '__label__'
            label = predix + str(y[i])
            line = doc + '\t' + label + '\n'
            f.write(line)

# %%
# 第一层分类训练
x = np.array(train['ITEM_NAME'])
y = np.array(train['TYPE1'])
x_train, y_train, x_test, y_test = train_test_split(x, y)
data_write('train_type1.txt', x_train, y_train)
data_write('test_type1.txt', x_test, y_test)
classifier = fasttext.supervised('train_type1.txt', '1/0.model', label_prefix='__label__')
# classifier = fasttext.load_model('1/0.model.bin', label_prefix='__label__')
result = classifier.test('test_type1.txt')
precision_l1 = result.precision
recall_l2 = result.recall
length = len(x)
print('样本数量：%d; 精确率：%f; 回报率：%f' % (length, precision_l1, recall_l2))
# Out:
# 样本数量：499447; 精确率：0.945221; 回报率：0.945221

# %%
# 第二层分类训练
precision2 = []
for i in range(len(type_dict)):
    x = np.array(train['ITEM_NAME'][type2_list[i]])
    y1 = np.array(train['TYPE2'][type2_list[i]])
    x_train, y1_train, x_test, y1_test = train_test_split(x, y1)
    data_write('train_type2.txt', x_train, y1_train)
    data_write('test_type2.txt', x_test, y1_test)
    classifier = fasttext.supervised('train_type2.txt', '2/'+str(i)+'.model', label_prefix='__label__')
    # classifier = fasttext.load_model('2/'+str(i)+'.model.bin', label_prefix='__label__')
    result = classifier.test('test_type2.txt')
    precision = result.precision
    precision2.append(precision)
    recall = result.recall
    length = len(x)
    print('样本数量：%d; 精确率：%f; 回报率：%f' % (length, precision, recall))
# Out:
# 样本数量：350; 精确率：1.000000; 回报率：1.000000
# 样本数量：2268; 精确率：0.666667; 回报率：0.666667
# 样本数量：22679; 精确率：0.968254; 回报率：0.968254
# 样本数量：14096; 精确率：0.948936; 回报率：0.948936
# 样本数量：80869; 精确率：0.957962; 回报率：0.957962
# 样本数量：31014; 精确率：0.998066; 回报率：0.998066
# 样本数量：1556; 精确率：0.910256; 回报率：0.910256
# 样本数量：1853; 精确率：0.763441; 回报率：0.763441
# 样本数量：10316; 精确率：0.982558; 回报率：0.982558
# 样本数量：1824; 精确率：0.782609; 回报率：0.782609
# 样本数量：36953; 精确率：0.938853; 回报率：0.938853
# 样本数量：82800; 精确率：0.981159; 回报率：0.981159
# 样本数量：477; 精确率：0.500000; 回报率：0.500000
# 样本数量：12322; 精确率：0.893031; 回报率：0.893031
# 样本数量：34691; 精确率：0.978674; 回报率：0.978674
# 样本数量：31515; 精确率：0.619924; 回报率：0.619924
# 样本数量：23756; 精确率：0.930135; 回报率：0.930135
# 样本数量：3831; 精确率：0.859375; 回报率：0.859375
# 样本数量：3541; 精确率：0.516854; 回报率：0.516854
# 样本数量：35557; 精确率：0.961192; 回报率：0.961192
# 样本数量：44304; 精确率：0.992780; 回报率：0.992780
# 样本数量：22875; 精确率：0.902098; 回报率：0.902098

# %%
# 第三层分类训练
precision3 = []
for i in range(len(type2_dict)):
    x = np.array(train['ITEM_NAME'][type3_list[i]])
    y1 = np.array(train['TYPE3'][type3_list[i]])
    x_train, y1_train, x_test, y1_test = train_test_split(x, y1)
    data_write('train_type3.txt', x_train, y1_train)
    data_write('test_type3.txt', x_test, y1_test)
    classifier = fasttext.supervised('train_type3.txt', '3/'+str(i)+'.model', label_prefix='__label__')
    # classifier = fasttext.load_model('3/'+str(i)+'.model.bin', label_prefix='__label__')
    result = classifier.test('test_type3.txt')
    precision = result.precision
    precision3.append(precision)
    recall = result.recall
    length = len(x)
    print('样本数量：%d; 精确率：%f; 回报率：%f' % (length, precision, recall))
# Out:
# 样本数量：350; 精确率：0.833333; 回报率：0.833333
# 样本数量：64; 精确率：0.500000; 回报率：0.500000
# 样本数量：198; 精确率：0.400000; 回报率：0.400000
# 样本数量：742; 精确率：0.868421; 回报率：0.868421
# 样本数量：286; 精确率：0.666667; 回报率：0.666667
# 样本数量：438; 精确率：0.363636; 回报率：0.363636
# 样本数量：232; 精确率：1.000000; 回报率：1.000000
# 样本数量：308; 精确率：0.125000; 回报率：0.125000
# 样本数量：2198; 精确率：0.945455; 回报率：0.945455
# 样本数量：7800; 精确率：0.876923; 回报率：0.876923
# 样本数量：5523; 精确率：0.920578; 回报率：0.920578
# 样本数量：357; 精确率：0.777778; 回报率：0.777778
# 样本数量：1009; 精确率：0.431373; 回报率：0.431373
# 样本数量：5792; 精确率：0.896552; 回报率：0.896552
# 样本数量：2695; 精确率：0.859259; 回报率：0.859259
# 样本数量：4025; 精确率：0.940594; 回报率：0.940594
# 样本数量：147; 精确率：1.000000; 回报率：1.000000
# 样本数量：2631; 精确率：0.871212; 回报率：0.871212
# 样本数量：606; 精确率：0.483871; 回报率：0.483871
# 样本数量：3992; 精确率：0.745000; 回报率：0.745000
# 样本数量：2618; 精确率：0.717557; 回报率：0.717557
# 样本数量：30367; 精确率：0.956550; 回报率：0.956550
# 样本数量：7031; 精确率：0.838068; 回报率：0.838068
# 样本数量：3453; 精确率：0.820809; 回报率：0.820809
# 样本数量：34773; 精确率：0.931570; 回报率：0.931570
# 样本数量：2627; 精确率：0.598485; 回报率：0.598485
# 样本数量：23068; 精确率：0.983536; 回报率：0.983536
# 样本数量：7946; 精确率：0.987437; 回报率：0.987437
# 样本数量：12; 精确率：1.000000; 回报率：1.000000
# 样本数量：48; 精确率：0.666667; 回报率：0.666667
# 样本数量：1471; 精确率：0.891892; 回报率：0.891892
# 样本数量：25; 精确率：1.000000; 回报率：1.000000
# 样本数量：150; 精确率：0.125000; 回报率：0.125000
# 样本数量：225; 精确率：0.750000; 回报率：0.750000
# 样本数量：432; 精确率：0.045455; 回报率：0.045455
# 样本数量：505; 精确率：0.346154; 回报率：0.346154
# 样本数量：541; 精确率：0.500000; 回报率：0.500000
# 样本数量：408; 精确率：0.238095; 回报率：0.238095
# 样本数量：6963; 精确率：0.977077; 回报率：0.977077
# 样本数量：1681; 精确率：0.929412; 回报率：0.929412
# 样本数量：251; 精确率：1.000000; 回报率：1.000000
# 样本数量：1013; 精确率：0.509804; 回报率：0.509804
# 样本数量：187; 精确率：0.400000; 回报率：0.400000
# 样本数量：1183; 精确率：0.450000; 回报率：0.450000
# 样本数量：78; 精确率：1.000000; 回报率：1.000000
# 样本数量：13; 精确率：1.000000; 回报率：1.000000
# 样本数量：363; 精确率：0.842105; 回报率：0.842105
# 样本数量：245; 精确率：1.000000; 回报率：1.000000
# 样本数量：329; 精确率：1.000000; 回报率：1.000000
# 样本数量：1645; 精确率：0.987952; 回报率：0.987952
# 样本数量：2436; 精确率：0.926230; 回报率：0.926230
# 样本数量：1121; 精确率：0.912281; 回报率：0.912281
# 样本数量：1221; 精确率：0.661290; 回报率：0.661290
# 样本数量：4111; 精确率：0.922330; 回报率：0.922330
# 样本数量：6082; 精确率：0.980328; 回报率：0.980328
# 样本数量：1925; 精确率：0.969072; 回报率：0.969072
# 样本数量：837; 精确率：1.000000; 回报率：1.000000
# 样本数量：714; 精确率：0.916667; 回报率：0.916667
# 样本数量：6464; 精确率：0.858025; 回报率：0.858025
# 样本数量：46; 精确率：0.333333; 回报率：0.333333
# 样本数量：1510; 精确率：0.828947; 回报率：0.828947
# 样本数量：1588; 精确率：0.637500; 回报率：0.637500
# 样本数量：327; 精确率：0.705882; 回报率：0.705882
# 样本数量：1502; 精确率：0.605263; 回报率：0.605263
# 样本数量：891; 精确率：0.133333; 回报率：0.133333
# 样本数量：1159; 精确率：0.879310; 回报率：0.879310
# 样本数量：2602; 精确率：0.954198; 回报率：0.954198
# 样本数量：198; 精确率：0.500000; 回报率：0.500000
# 样本数量：1759; 精确率：0.761364; 回报率：0.761364
# 样本数量：1992; 精确率：0.710000; 回报率：0.710000
# 样本数量：2608; 精确率：0.885496; 回报率：0.885496
# 样本数量：103; 精确率：1.000000; 回报率：1.000000
# 样本数量：63999; 精确率：0.948750; 回报率：0.948750
# 样本数量：22; 精确率：1.000000; 回报率：1.000000
# 样本数量：12317; 精确率：0.931818; 回报率：0.931818
# 样本数量：244; 精确率：0.461538; 回报率：0.461538
# 样本数量：65; 精确率：1.000000; 回报率：1.000000
# 样本数量：20; 精确率：1.000000; 回报率：1.000000
# 样本数量：47; 精确率：0.666667; 回报率：0.666667
# 样本数量：101; 精确率：0.166667; 回报率：0.166667
# 样本数量：89; 精确率：1.000000; 回报率：1.000000
# 样本数量：984; 精确率：0.240000; 回报率：0.240000
# 样本数量：1633; 精确率：0.731707; 回报率：0.731707
# 样本数量：484; 精确率：1.000000; 回报率：1.000000
# 样本数量：4705; 精确率：0.817797; 回报率：0.817797
# 样本数量：1040; 精确率：0.461538; 回报率：0.461538
# 样本数量：2401; 精确率：0.933884; 回报率：0.933884
# 样本数量：986; 精确率：0.240000; 回报率：0.240000
# 样本数量：151; 精确率：0.875000; 回报率：0.875000
# 样本数量：428; 精确率：0.227273; 回报率：0.227273
# 样本数量：29435; 精确率：0.963995; 回报率：0.963995
# 样本数量：174; 精确率：1.000000; 回报率：1.000000
# 样本数量：1435; 精确率：0.597222; 回报率：0.597222
# 样本数量：2440; 精确率：0.893443; 回报率：0.893443
# 样本数量：628; 精确率：0.843750; 回报率：0.843750
# 样本数量：344; 精确率：0.000000; 回报率：0.000000
# 样本数量：1088; 精确率：0.909091; 回报率：0.909091
# 样本数量：13; 精确率：1.000000; 回报率：1.000000
# 样本数量：253; 精确率：0.153846; 回报率：0.153846
# 样本数量：409; 精确率：0.428571; 回报率：0.428571
# 样本数量：954; 精确率：0.354167; 回报率：0.354167
# 样本数量：725; 精确率：0.162162; 回报率：0.162162
# 样本数量：693; 精确率：0.314286; 回报率：0.314286
# 样本数量：240; 精确率：0.000000; 回报率：0.000000
# 样本数量：17; 精确率：1.000000; 回报率：1.000000
# 样本数量：758; 精确率：0.289474; 回报率：0.289474
# 样本数量：75; 精确率：0.750000; 回报率：0.750000
# 样本数量：355; 精确率：0.277778; 回报率：0.277778
# 样本数量：1561; 精确率：0.443038; 回报率：0.443038
# 样本数量：339; 精确率：0.529412; 回报率：0.529412
# 样本数量：954; 精确率：0.645833; 回报率：0.645833
# 样本数量：348; 精确率：0.000000; 回报率：0.000000
# 样本数量：2279; 精确率：0.500000; 回报率：0.500000
# 样本数量：173; 精确率：0.222222; 回报率：0.222222
# 样本数量：150; 精确率：0.250000; 回报率：0.250000
# 样本数量：634; 精确率：0.031250; 回报率：0.031250
# 样本数量：1098; 精确率：0.436364; 回报率：0.436364
# 样本数量：383; 精确率：0.050000; 回报率：0.050000
# 样本数量：144; 精确率：0.375000; 回报率：0.375000
# 样本数量：229; 精确率：0.166667; 回报率：0.166667
# 样本数量：346; 精确率：0.666667; 回报率：0.666667
# 样本数量：80; 精确率：1.000000; 回报率：1.000000
# 样本数量：457; 精确率：0.173913; 回报率：0.173913
# 样本数量：38; 精确率：1.000000; 回报率：1.000000
# 样本数量：14; 精确率：1.000000; 回报率：1.000000
# 样本数量：46; 精确率：0.333333; 回报率：0.333333
# 样本数量：4664; 精确率：0.623932; 回报率：0.623932
# 样本数量：792; 精确率：0.200000; 回报率：0.200000
# 样本数量：283; 精确率：0.333333; 回报率：0.333333
# 样本数量：965; 精确率：0.489796; 回报率：0.489796
# 样本数量：1235; 精确率：0.258065; 回报率：0.258065
# 样本数量：1159; 精确率：0.155172; 回报率：0.155172
# 样本数量：149; 精确率：0.125000; 回报率：0.125000
# 样本数量：758; 精确率：0.236842; 回报率：0.236842
# 样本数量：681; 精确率：0.257143; 回报率：0.257143
# 样本数量：117; 精确率：0.333333; 回报率：0.333333
# 样本数量：469; 精确率：0.291667; 回报率：0.291667
# 样本数量：379; 精确率：0.368421; 回报率：0.368421
# 样本数量：524; 精确率：0.518519; 回报率：0.518519
# 样本数量：4070; 精确率：0.392157; 回报率：0.392157
# 样本数量：73; 精确率：0.250000; 回报率：0.250000
# 样本数量：14305; 精确率：0.956704; 回报率：0.956704
# 样本数量：4615; 精确率：0.922078; 回报率：0.922078
# 样本数量：4836; 精确率：0.896694; 回报率：0.896694
# 样本数量：1083; 精确率：0.581818; 回报率：0.581818
# 样本数量：146; 精确率：0.000000; 回报率：0.000000
# 样本数量：1276; 精确率：0.890625; 回报率：0.890625
# 样本数量：423; 精确率：0.454545; 回报率：0.454545
# 样本数量：393; 精确率：0.150000; 回报率：0.150000
# 样本数量：510; 精确率：0.076923; 回报率：0.076923
# 样本数量：810; 精确率：0.829268; 回报率：0.829268
# 样本数量：492; 精确率：0.480000; 回报率：0.480000
# 样本数量：342; 精确率：0.277778; 回报率：0.277778
# 样本数量：98; 精确率：0.600000; 回报率：0.600000
# 样本数量：500; 精确率：0.320000; 回报率：0.320000
# 样本数量：305; 精确率：0.937500; 回报率：0.937500
# 样本数量：26; 精确率：0.000000; 回报率：0.000000
# 样本数量：84; 精确率：0.000000; 回报率：0.000000
# 样本数量：121; 精确率：0.285714; 回报率：0.285714
# 样本数量：14; 精确率：1.000000; 回报率：1.000000
# 样本数量：55; 精确率：1.000000; 回报率：1.000000
# 样本数量：271; 精确率：0.285714; 回报率：0.285714
# 样本数量：40; 精确率：1.000000; 回报率：1.000000
# 样本数量：64; 精确率：0.500000; 回报率：0.500000
# 样本数量：14; 精确率：1.000000; 回报率：1.000000
# 样本数量：35; 精确率：1.000000; 回报率：1.000000
# 样本数量：215; 精确率：0.181818; 回报率：0.181818
# 样本数量：55; 精确率：1.000000; 回报率：1.000000
# 样本数量：1213; 精确率：1.000000; 回报率：1.000000
# 样本数量：7072; 精确率：0.819209; 回报率：0.819209
# 样本数量：13404; 精确率：0.932936; 回报率：0.932936
# 样本数量：2795; 精确率：0.878571; 回报率：0.878571
# 样本数量：159; 精确率：0.500000; 回报率：0.500000
# 样本数量：5671; 精确率：0.894366; 回报率：0.894366
# 样本数量：3042; 精确率：0.928105; 回报率：0.928105
# 样本数量：602; 精确率：0.548387; 回报率：0.548387
# 样本数量：1599; 精确率：0.637500; 回报率：0.637500
# 样本数量：35570; 精确率：0.934233; 回报率：0.934233
# 样本数量：2948; 精确率：0.871622; 回报率：0.871622
# 样本数量：5786; 精确率：0.934483; 回报率：0.934483
# 样本数量：60; 精确率：1.000000; 回报率：1.000000
# 样本数量：316; 精确率：0.312500; 回报率：0.312500
# 样本数量：297; 精确率：0.666667; 回报率：0.666667
# 样本数量：70; 精确率：0.250000; 回报率：0.250000
# 样本数量：987; 精确率：0.640000; 回报率：0.640000
# 样本数量：10168; 精确率：0.966601; 回报率：0.966601
# 样本数量：3648; 精确率：0.918033; 回报率：0.918033
# 样本数量：491; 精确率：0.480000; 回报率：0.480000
# 样本数量：118; 精确率：0.000000; 回报率：0.000000
# 样本数量：680; 精确率：0.970588; 回报率：0.970588
# 样本数量：6040; 精确率：0.943709; 回报率：0.943709

# %%
# 第一层分类精确率
print('第一层精确率：%f' % (precision_l1))

# 第二层分类平均精确率计算
pre_2_aver = 0
for i in range(len(type_dict)):
    length = len(type2_list[i])
    pre_2_aver += length*1.0/len(train)*precision2[i]
print('第二层平均精确率：%f' % (pre_2_aver))

# 第三层分类平均精确率计算
pre_3_aver = 0
for i in range(len(type2_dict)):
    length = len(type3_list[i])
    pre_3_aver += length*1.0/len(train)*precision3[i]
print('第三层平均精确率：%f' % (pre_3_aver))
# Out:
# 第一层精确率：0.945221
# 第二层平均精确率：0.934423
# 第三层平均精确率：0.866855

# %%
# 450万数据的分层预测(以0-1000样本为例)
test = pd.read_csv('test.tsv', sep='\t', encoding='gb18030')
pre_labels = []
classifier1 = fasttext.load_model('1/0.model.bin', label_prefix='__label__')
i = 0
for line in test['ITEM_NAME'][:1000]:
    line = jieba.cut(line.strip(), cut_all=False)
    line = [str(' '.join(list(line)))]
    
    label1 = classifier1.predict(line)[0][0]
    num1 = type_dict[label1]
    
    classifier2 = fasttext.load_model('2/'+str(num1)+'.model.bin', label_prefix='__label__')
    label2 = classifier2.predict(line)[0][0]
    num2 = type2_dict[label2]
    
    classifier3 = fasttext.load_model('3/'+str(num2)+'.model.bin', label_prefix='__label__')
    label3 = classifier3.predict(line)[0][0]
    
    label = str(label1) + '--' + str(label2) + '--' + str(label3)
    pre_labels.append(label)
    if(i%200==0):
        print(i)
    i = i+1
# Out:
# 0
# 200
# 400
# 600
# 800

# %%
# 预测结果保存
pre_test = pd.DataFrame({'ITEM_NAME':test['ITEM_NAME'][:1000], 'PRE_LABEL':pre_labels})
pre_test.to_csv('predict_result/pre_test.csv', sep=',', header=True)

# %%
pre_test.head()
# Out:
#                                       ITEM_NAME         PRE_LABEL
# 0                                腾讯QQ蓝钻贵族34个月直充  本地生活--游戏充值--QQ充值
# 1   腾讯QQ币24元24QQ币24个直充24Q币24个Q币24个QB/24QQB★自动充值  本地生活--游戏充值--游戏点卡
# 2   腾讯QQ币101元101QQ币101个直充101Q币101个Q币101个QB★自动充值  本地生活--游戏充值--游戏点卡
# 3  腾讯QQ币402元 402QB 402QQ币402个 402Q币 402个Q币 自动充值  本地生活--游戏充值--游戏点卡
# 4  腾讯QQ币380元 380QB 380QQ币380个 380Q币 380个Q币 自动充值  本地生活--游戏充值--游戏点卡
